# %% [markdown]
# # Clone and install requirement

# %%
import os

folder_path = '/Ai_Project/'
if os.path.isdir(folder_path):
  pass
else:
  # !git clone https://github.com/LWL220184016/AI_Project.git
  # !cp -r /content/AI_Project/RAG_Chatbot-main/final /content/final
  # !cp ./AI_Project/RAG_Chatbot-main/requirement.txt /content/requirement.txt

# !pip install -r requirement.txt
# Out:
# Running cells with '.conda (Python 3.11.14)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p /home/user/AI_Project/.conda ipykernel --update-deps --force-reinstall'

# %% [markdown]
# # load model and data

# %%
from final.object_detect.detr_resnet_50.model import detr_resnet_50
from final.object_detect.yolo.config import model_config, train_config

model_cfg = model_config()
train_cfg = train_config()

model = detr_resnet_50(model_cfg=model_cfg, train_cfg=train_cfg)
model.setup_data()
model.show_dataset_sample()

# %% [markdown]
# # Train

# %%
model.train()
# Out:
# 1
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-2444096474.py in <cell line: 0>()
# ----> 1 model.train(dataLoader=train_loader)
#
# /content/final/object_detect/yolo/yolo.py in train(self, dataLoader)
#      56             running_loss = 0.0
#      57
# ---> 58             for step, (imgs, targets) in enumerate(dataLoader):
#      59                 imgs = [img.to(self.device) for img in imgs]
#      60                 targets = [{k: torch.tensor(v).to(self.device) for k, v in t.items()} for t in targets]
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     732                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733                 self._reset()  # type: ignore[call-arg]
# --> 734             data = self._next_data()
#     735             self._num_yielded += 1
# ...

# %% [markdown]
# # Evaluate

# %%
result = model.evaluate()
print("result: ", result)
