# %% [markdown]
# # Data

# %%
Construction-PPE

# %% [markdown]
# # Model

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt") 

EfficientDet

self implement model

# %% [markdown]
# # Train
